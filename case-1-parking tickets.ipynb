# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('./data/Parking_Violations_Issued_-_Fiscal_Year_2014__August_2013___June_2014_.csv', quotechar='"')
data.head()
# Out:
#    Summons Number Plate ID Registration State Plate Type  Issue Date  \
# 0      1369808562  CSY6322                 NY        PAS  06/30/2014
# 1      1371533763  FXL4398                 NY        PAS  06/30/2014
# 2      1370617069  82553JZ                 NY        COM  06/30/2014
# 3      1370413026  ETU8952                 NY        PAS  06/30/2014
# 4      1370402405  EBV8572                 NY        SRF  06/30/2014
#
#    Violation Code Vehicle Body Type Vehicle Make Issuing Agency  Street Code1  \
# 0              19              SUBN        TOYOT              P             0
# 1              46              SUBN        SATUR              P             0
# 2              95               VAN         FORD              P         15410
# 3              21              SUBN        TOYOT              S         26130
# 4              21               SDN        TOYOT              S         50770
#
#             ...             Vehicle Color  Unregistered Vehicle?  \
# 0           ...                     WHITE                      0
# 1           ...                      BLUE                      0
# 2           ...                     WHITE                      0
# 3           ...                      BLUE                      0
# 4           ...                      GREY                      0
#
#    Vehicle Year  Meter Number  Feet From Curb  Violation Post Code  \
# 0             0             -               0                  NaN
# 1          2005             -               0                  NaN
# 2          2012             -               0                  NaN
# 3          2010             -               0                  NaN
# 4          2007             -               0                  NaN
#
#    Violation Description No Standing or Stopping Violation  Hydrant Violation  \
# 0                    NaN                               NaN                NaN
# 1                    NaN                               NaN                NaN
# 2                    NaN                               NaN                NaN
# 3                    NaN                               NaN                NaN
# 4                    NaN                               NaN                NaN
#
#   Double Parking Violation
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
#
# [5 rows x 43 columns]

# %%
data_by_register = data.groupby('Registration State').count().sort_values('Summons Number', ascending=0)['Summons Number']
data_by_register.head()
# Out:
# Registration State
# NY    3692
# NJ     298
# 99     171
# PA     137
# CT      61
# Name: Summons Number, dtype: int64

# %%
data.columns
# Out:
# Index(['Summons Number', 'Plate ID', 'Registration State', 'Plate Type',
#        'Issue Date', 'Violation Code', 'Vehicle Body Type', 'Vehicle Make',
#        'Issuing Agency', 'Street Code1', 'Street Code2', 'Street Code3',
#        'Vehicle Expiration Date', 'Violation Location', 'Violation Precinct',
#        'Issuer Precinct', 'Issuer Code', 'Issuer Command', 'Issuer Squad',
#        'Violation Time', 'Time First Observed', 'Violation County',
#        'Violation In Front Of Or Opposite', 'House Number', 'Street Name',
#        'Intersecting Street', 'Date First Observed', 'Law Section',
#        'Sub Division', 'Violation Legal Code', 'Days Parking In Effect    ',
#        'From Hours In Effect', 'To Hours In Effect', 'Vehicle Color',
#        'Unregistered Vehicle?', 'Vehicle Year', 'Meter Number',
#        'Feet From Curb', 'Violation Post Code', 'Violation Description',
#        'No Standing or Stopping Violation', 'Hydrant Violation',
#        'Double Parking Violation'],
#       dtype='object')

# %%
data_by_violation = data[data['Violation Code'] == 40].groupby('Violation Code').count().sort_values('Violation Code', ascending=0).loc['Issuer Precinct']
data_by_violation.head()
# Out:
# -------------------------------------------------------------------------
# KeyError                                Traceback (most recent call last)
# /data/data/com.termux/files/usr/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2521             try:
# -> 2522                 return self._engine.get_loc(key)
#    2523             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Violation Code'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                Traceback (most recent call last)
# <ipython-input-5-280c4b2484bb> in <module>()
# ----> 1 data_by_violation = data[data['Violation Code'] == 40].groupby('Violation Code').count().sort_values('Violation Code', ascending=0).loc['Issuer Precinct']
#       2 data_by_violation.head()
#
# /data/data/com.termux/files/usr/lib/python3.6/site-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    3617
#    3618             by = by[0]
# -> 3619             k = self.xs(by, axis=other_axis).values
#    3620             if k.ndim == 2:
#    3621
#
# /data/data/com.termux/files/usr/lib/python3.6/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    2333
#    2334         if axis == 1:
# -> 2335             return self[key]
#    2336
#    2337         self._consolidate_inplace()
#
# /data/data/com.termux/files/usr/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# /data/data/com.termux/files/usr/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# /data/data/com.termux/files/usr/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# /data/data/com.termux/files/usr/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3836
#    3837             if not isna(item):
# -> 3838                 loc = self.items.get_loc(item)
#    3839             else:
#    3840                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# /data/data/com.termux/files/usr/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2522                 return self._engine.get_loc(key)
#    2523             except KeyError:
# -> 2524                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2525
#    2526         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Violation Code'

# %%
data_plate = data[data['Violation Code'] == 40].groupby('Plate ID').count()
data_plate.reset_index(inplace=True)
data_plate.sort_values('Plate ID', ascending=0, inplace=True)
data_plate.head()
# Out:
#     Plate ID  Summons Number  Registration State  Plate Type  Issue Date  \
# 432   ZKP114               1                   1           1           1
# 431   YTV21D               1                   1           1           1
# 430   Y67CYK               1                   1           1           1
# 429   XZ876G               1                   1           1           1
# 428   XANR39               1                   1           1           1
#
#      Violation Code  Vehicle Body Type  Vehicle Make  Issuing Agency  \
# 432               1                  1             1               1
# 431               1                  1             1               1
# 430               1                  1             1               1
# 429               1                  1             1               1
# 428               1                  0             1               1
#
#      Street Code1            ...             Vehicle Color  \
# 432             1            ...                         1
# 431             1            ...                         1
# 430             1            ...                         1
# 429             1            ...                         1
# 428             1            ...                         1
#
#      Unregistered Vehicle?  Vehicle Year  Meter Number  Feet From Curb  \
# 432                      1             1             1               1
# 431                      1             1             1               1
# 430                      1             1             1               1
# 429                      1             1             1               1
# 428                      1             1             1               1
#
#      Violation Post Code  Violation Description  \
# 432                    0                      0
# 431                    0                      0
# 430                    0                      0
# 429                    0                      0
# 428                    0                      0
#
#      No Standing or Stopping Violation  Hydrant Violation  \
# 432                                  0                  0
# 431                                  0                  0
# 430                                  0                  0
# 429                                  0                  0
# 428                                  0                  0
#
#      Double Parking Violation
# 432                         0
# 431                         0
# 430                         0
# 429                         0
# 428                         0
#
# [5 rows x 43 columns]

# %%
data_car = data[(data['Violation Code']==40) & (data['Plate ID']=='ZKP114')]
data_car
# Out:
#       Summons Number Plate ID Registration State Plate Type  Issue Date  \
# 1703      1360908833   ZKP114                 OK        PAS  12/22/2014
#
#       Violation Code Vehicle Body Type Vehicle Make Issuing Agency  \
# 1703              40              DELV          GMC              P
#
#       Street Code1           ...             Vehicle Color  \
# 1703         68930           ...                     WHITE
#
#       Unregistered Vehicle?  Vehicle Year  Meter Number  Feet From Curb  \
# 1703                      0             0             -               0
#
#       Violation Post Code  Violation Description  \
# 1703                  NaN                    NaN
#
#      No Standing or Stopping Violation  Hydrant Violation  \
# 1703                               NaN                NaN
#
#      Double Parking Violation
# 1703                      NaN
#
# [1 rows x 43 columns]

# %%
data_color = data.groupby('Vehicle Color').count().sort_values('Summons Number', ascending=0)['Summons Number']
data_color.head()
# Out:
# Vehicle Color
# WHITE    778
# WH       394
# BLACK    338
# GY       303
# BLK      266
# Name: Summons Number, dtype: int64

# %%
table = data
table['minute'] = table['Violation Time'].apply(lambda x: str(x)[2:4])
data_by_minute = data.groupby('minute').count()
data_by_minute.sort_values(by='Summons Number', inplace=True,ascending=False)
data_by_minute.head()
# Out:
#         Summons Number  Plate ID  Registration State  Plate Type  Issue Date  \
# minute
# 00                 228       228                 228         228         228
# 15                 209       209                 209         209         209
# 45                 194       194                 194         194         194
# 50                 191       191                 191         191         191
# 40                 183       183                 183         183         183
#
#         Violation Code  Vehicle Body Type  Vehicle Make  Issuing Agency  \
# minute
# 00                 228                223           216             228
# 15                 209                202           194             209
# 45                 194                184           188             194
# 50                 191                185           187             191
# 40                 183                177           168             183
#
#         Street Code1            ...             Vehicle Color  \
# minute                          ...
# 00               228            ...                       217
# 15               209            ...                       204
# 45               194            ...                       189
# 50               191            ...                       188
# 40               183            ...                       181
#
#         Unregistered Vehicle?  Vehicle Year  Meter Number  Feet From Curb  \
# minute
# 00                        228           228           228             228
# 15                        209           209           209             209
# 45                        194           194           194             194
# 50                        191           191           191             191
# 40                        183           183           183             183
#
#         Violation Post Code  Violation Description  \
# minute
# 00                        0                      0
# 15                        0                      0
# 45                        0                      0
# 50                        0                      0
# 40                        0                      0
#
#         No Standing or Stopping Violation  Hydrant Violation  \
# minute
# 00                                      0                  0
# 15                                      0                  0
# 45                                      0                  0
# 50                                      0                  0
# 40                                      0                  0
#
#         Double Parking Violation
# minute
# 00                             0
# 15                             0
# 45                             0
# 50                             0
# 40                             0
#
# [5 rows x 43 columns]

# %%
data['time'] = pd.to_datetime((data['Issue Date'] + ' ' + data['Violation Time'] + 'M').str.replace(" 00", " 12"), format='%m/%d/%Y %I%M%p', errors='coerce')
data.index = data['time']
data_new  = data
data_new['WeekDay'] = data_new.index.weekday
data_new['Hour'] = data_new.index.hour
data_new['Minute'] = data_new.index.minute

data_plot = data_new['Minute'].hist(bins=60, range=(0, 60))
data_plot.set_xlabel('Minute of Hour')
data_plot.set_ylabel('Count')
data_plot.set_title('Minute of Hour for Tickets Given')
# Out:
# Text(0.5,1,'Minute of Hour for Tickets Given')
